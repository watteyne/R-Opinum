# %% [markdown]
# # Revue détaillée des timezones dans Datahub
# ## Environnement de test
# ### Compte
# Nous utilisons le compte 959, Calculated Variables
# ### Sites
# Nous nous basons sur 3 sites
# * UTC, qui est en ... UTC
# * Local, qui est en CE(S)T
# * FarAway, qui est en HKT (Hong Kong, pas de changement d'heure)
# ### Sources
# Nous nous basons sur x sources par site (certaines sont redondantes)
# * UTC, qui est en ... UTC
# * Site_timezone qui a la même timezone que son site
# * Brussels, qui est en CE(S)T
# * Site_timezone_adapted, qui est en UTC lors du chargement de données puis passe en la timezone du site
# * UTC_shared, qui est en UTC et est partagée par les 3 sites
# * Brussels_shared, qui est en CE(S)T et est partagée par les 3 sites
# # Variables
# Sur chaque source, nous avons 5 variables
# * unaware, qui reçoit les données sans mention de timezone
# * unaware_brussels, qui reçoit les données, préalablement mises en CE(S)T,  sans mention de timezone
# * utc, qui reçoit les données en UTC en format Zulu (Z)
# * utc_2, qui reçoit les données en UTC en format +00:00
# * brussels, qui reçoit les données en CE(S)T

# %% [markdown]
# ## Vérification des données
# ### UTC-UTC-unaware
# <font color=green>Sans problèmes, heureusement.</font><br>
# CSV:
# ```
# 2021-10-30T22:00:00,806515533.0493927,UTC-UTC,unaware
# 2021-10-30T23:00:00,1304969544.9286566,UTC-UTC,unaware
# 2021-10-31T00:00:00,2111485077.9780493,UTC-UTC,unaware
# 2021-10-31T01:00:00,3416454622.906706,UTC-UTC,unaware
# 2021-10-31T02:00:00,5527939700.884755,UTC-UTC,unaware
# 2021-10-31T03:00:00,8944394323.791462,UTC-UTC,unaware
# 2021-10-31T04:00:00,14472334024.676216,UTC-UTC,unaware
# ```
# API get data (UTC)
# ```
# [
#   {
#     "date": "2021-10-30T23:00:00",
#     "variableId": 2441330,
#     "rawValue": 1304969544.9286566,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T22:00:00",
#     "variableId": 2441330,
#     "rawValue": 806515533.0493927,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T04:00:00",
#     "variableId": 2441330,
#     "rawValue": 14472334024.676216,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T03:00:00",
#     "variableId": 2441330,
#     "rawValue": 8944394323.791462,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441330,
#     "rawValue": 5527939700.884755,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T01:00:00",
#     "variableId": 2441330,
#     "rawValue": 3416454622.906706,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T00:00:00",
#     "variableId": 2441330,
#     "rawValue": 2111485077.9780493,
#     "unitId": 0
#   }
# ]
# ```
# API get data (Local)
# ```
# [
#   {
#     "date": "2021-10-30T23:00:00",
#     "variableId": 2441330,
#     "rawValue": 1304969544.9286566,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T22:00:00",
#     "variableId": 2441330,
#     "rawValue": 806515533.0493927,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T04:00:00",
#     "variableId": 2441330,
#     "rawValue": 14472334024.676216,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T03:00:00",
#     "variableId": 2441330,
#     "rawValue": 8944394323.791462,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441330,
#     "rawValue": 5527939700.884755,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T01:00:00",
#     "variableId": 2441330,
#     "rawValue": 3416454622.906706,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T00:00:00",
#     "variableId": 2441330,
#     "rawValue": 2111485077.9780493,
#     "unitId": 0
#   }
# ]
# ```
# ### Local-UTC-unaware
# <font color=green>Les valeurs ont bien été stockées telles quelles.
# Le 00:00 UTC est bien mis à 02:00 (heure d'été) pour un get data en local.
# Le 00:10 UTC est bien mis à 02:00 (heure d'hiver) pour un get data en local.</font><br>
# CSV:
# ```
# 2021-10-30T22:00:00,806515533.0493927,Local-UTC,unaware
# 2021-10-30T23:00:00,1304969544.9286566,Local-UTC,unaware
# 2021-10-31T00:00:00,2111485077.9780493,Local-UTC,unaware
# 2021-10-31T01:00:00,3416454622.906706,Local-UTC,unaware
# 2021-10-31T02:00:00,5527939700.884755,Local-UTC,unaware
# 2021-10-31T03:00:00,8944394323.791462,Local-UTC,unaware
# 2021-10-31T04:00:00,14472334024.676216,Local-UTC,unaware
# ```
# API get data (UTC)
# ```
# [
#   {
#     "date": "2021-10-30T23:00:00",
#     "variableId": 2441331,
#     "rawValue": 1304969544.9286566,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T22:00:00",
#     "variableId": 2441331,
#     "rawValue": 806515533.0493927,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T04:00:00",
#     "variableId": 2441331,
#     "rawValue": 14472334024.676216,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T03:00:00",
#     "variableId": 2441331,
#     "rawValue": 8944394323.791462,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441331,
#     "rawValue": 5527939700.884755,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T01:00:00",
#     "variableId": 2441331,
#     "rawValue": 3416454622.906706,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T00:00:00",
#     "variableId": 2441331,
#     "rawValue": 2111485077.9780493,
#     "unitId": 0
#   }
# ]
# ```
# API get data (Local)
# ```
# [
#   {
#     "date": "2021-10-31T01:00:00",
#     "variableId": 2441331,
#     "rawValue": 1304969544.9286566,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T00:00:00",
#     "variableId": 2441331,
#     "rawValue": 806515533.0493927,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T23:00:00",
#     "variableId": 2441331,
#     "rawValue": 498454011.8792638,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T22:00:00",
#     "variableId": 2441331,
#     "rawValue": 308061521.1701289,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T04:00:00",
#     "variableId": 2441331,
#     "rawValue": 8944394323.791462,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T03:00:00",
#     "variableId": 2441331,
#     "rawValue": 5527939700.884755,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441331,
#     "rawValue": 3416454622.906706,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441331,
#     "rawValue": 2111485077.9780493,
#     "unitId": 0
#   }
# ]
# ```
# ### UTC-Brussels-unaware
# <font color=orange>On a choisi de mettre l'ambigu 02:00 Brussels à 01:00 UTC mais 00:00 UTC était tout aussi plausible</font><br>
# CSV:
# ```
# 2021-10-30T22:00:00,806515533.0493927,UTC-Brussels,unaware
# 2021-10-30T23:00:00,1304969544.9286566,UTC-Brussels,unaware
# 2021-10-31T00:00:00,2111485077.9780493,UTC-Brussels,unaware
# 2021-10-31T01:00:00,3416454622.906706,UTC-Brussels,unaware
# 2021-10-31T02:00:00,5527939700.884755,UTC-Brussels,unaware
# 2021-10-31T03:00:00,8944394323.791462,UTC-Brussels,unaware
# 2021-10-31T04:00:00,14472334024.676216,UTC-Brussels,unaware
# ```
# API get data (UTC)
# ```
# [
#   {
#     "date": "2021-10-30T23:00:00",
#     "variableId": 2441336,
#     "rawValue": 3416454622.906706,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T22:00:00",
#     "variableId": 2441336,
#     "rawValue": 2111485077.9780493,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T04:00:00",
#     "variableId": 2441336,
#     "rawValue": 23416728348.467678,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T03:00:00",
#     "variableId": 2441336,
#     "rawValue": 14472334024.676216,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441336,
#     "rawValue": 8944394323.791462,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T01:00:00",
#     "variableId": 2441336,
#     "rawValue": 5527939700.884755,
#     "unitId": 0
#   }
# ]
# ```
# API get data (Local)
# ```
# [
#   {
#     "date": "2021-10-30T23:00:00",
#     "variableId": 2441336,
#     "rawValue": 3416454622.906706,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T22:00:00",
#     "variableId": 2441336,
#     "rawValue": 2111485077.9780493,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T04:00:00",
#     "variableId": 2441336,
#     "rawValue": 23416728348.467678,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T03:00:00",
#     "variableId": 2441336,
#     "rawValue": 14472334024.676216,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441336,
#     "rawValue": 8944394323.791462,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T01:00:00",
#     "variableId": 2441336,
#     "rawValue": 5527939700.884755,
#     "unitId": 0
#   }
# ]
# ```
# ### UTC-Site_timezone-unaware
# <font color=green>Sans problèmes, heureusement.</font><br>
# CSV:
# ```
# 2021-10-30T22:00:00,806515533.0493927,UTC-Site_timezone,unaware
# 2021-10-30T23:00:00,1304969544.9286566,UTC-Site_timezone,unaware
# 2021-10-31T00:00:00,2111485077.9780493,UTC-Site_timezone,unaware
# 2021-10-31T01:00:00,3416454622.906706,UTC-Site_timezone,unaware
# 2021-10-31T02:00:00,5527939700.884755,UTC-Site_timezone,unaware
# 2021-10-31T03:00:00,8944394323.791462,UTC-Site_timezone,unaware
# 2021-10-31T04:00:00,14472334024.676216,UTC-Site_timezone,unaware
# ```
# API get data (UTC)
# ```
# [
#   {
#     "date": "2021-10-30T23:00:00",
#     "variableId": 2441333,
#     "rawValue": 1304969544.9286566,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T22:00:00",
#     "variableId": 2441333,
#     "rawValue": 806515533.0493927,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T04:00:00",
#     "variableId": 2441333,
#     "rawValue": 14472334024.676216,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T03:00:00",
#     "variableId": 2441333,
#     "rawValue": 8944394323.791462,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441333,
#     "rawValue": 5527939700.884755,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T01:00:00",
#     "variableId": 2441333,
#     "rawValue": 3416454622.906706,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T00:00:00",
#     "variableId": 2441333,
#     "rawValue": 2111485077.9780493,
#     "unitId": 0
#   }
# ]
# ```
# API get data (Local)
# ```
# [
#   {
#     "date": "2021-10-30T23:00:00",
#     "variableId": 2441333,
#     "rawValue": 1304969544.9286566,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T22:00:00",
#     "variableId": 2441333,
#     "rawValue": 806515533.0493927,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T04:00:00",
#     "variableId": 2441333,
#     "rawValue": 14472334024.676216,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T03:00:00",
#     "variableId": 2441333,
#     "rawValue": 8944394323.791462,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441333,
#     "rawValue": 5527939700.884755,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T01:00:00",
#     "variableId": 2441333,
#     "rawValue": 3416454622.906706,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T00:00:00",
#     "variableId": 2441333,
#     "rawValue": 2111485077.9780493,
#     "unitId": 0
#   }
# ]
# ```
# ### Local-Site_timezone-unaware
# <font color=orange>On a choisi de mettre l'ambigu 02:00 Brussels à 01:00 UTC mais 00:00 UTC était tout aussi plausible</font><br>
# CSV:
# ```
# 2021-10-30T22:00:00,806515533.0493927,Local-Site_timezone,unaware
# 2021-10-30T23:00:00,1304969544.9286566,Local-Site_timezone,unaware
# 2021-10-31T00:00:00,2111485077.9780493,Local-Site_timezone,unaware
# 2021-10-31T01:00:00,3416454622.906706,Local-Site_timezone,unaware
# 2021-10-31T02:00:00,5527939700.884755,Local-Site_timezone,unaware
# 2021-10-31T03:00:00,8944394323.791462,Local-Site_timezone,unaware
# 2021-10-31T04:00:00,14472334024.676216,Local-Site_timezone,unaware
# ```
# API get data (UTC)
# ```
# [
#   {
#     "date": "2021-10-30T23:00:00",
#     "variableId": 2441334,
#     "rawValue": 3416454622.906706,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T22:00:00",
#     "variableId": 2441334,
#     "rawValue": 2111485077.9780493,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T04:00:00",
#     "variableId": 2441334,
#     "rawValue": 23416728348.467678,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T03:00:00",
#     "variableId": 2441334,
#     "rawValue": 14472334024.676216,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441334,
#     "rawValue": 8944394323.791462,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T01:00:00",
#     "variableId": 2441334,
#     "rawValue": 5527939700.884755,
#     "unitId": 0
#   }
# ]
# ```
# API get data (Local)
# ```
# [
#   {
#     "date": "2021-10-31T01:00:00",
#     "variableId": 2441334,
#     "rawValue": 3416454622.906706,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T00:00:00",
#     "variableId": 2441334,
#     "rawValue": 2111485077.9780493,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T23:00:00",
#     "variableId": 2441334,
#     "rawValue": 1304969544.9286566,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T22:00:00",
#     "variableId": 2441334,
#     "rawValue": 806515533.0493927,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T04:00:00",
#     "variableId": 2441334,
#     "rawValue": 14472334024.676216,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T03:00:00",
#     "variableId": 2441334,
#     "rawValue": 8944394323.791462,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441334,
#     "rawValue": 5527939700.884755,
#     "unitId": 0
#   }
# ]
# ```
# ### FarAway-Site_timezone-unaware
# <font color=green>Les heures UTC sont bien 8 heures avant l'heure locale</font><br>
# CSV:
# ```
# 2021-10-30T22:00:00,806515533.0493927,Local-Site_timezone,unaware
# 2021-10-30T23:00:00,1304969544.9286566,Local-Site_timezone,unaware
# 2021-10-31T00:00:00,2111485077.9780493,Local-Site_timezone,unaware
# 2021-10-31T01:00:00,3416454622.906706,Local-Site_timezone,unaware
# 2021-10-31T02:00:00,5527939700.884755,Local-Site_timezone,unaware
# 2021-10-31T03:00:00,8944394323.791462,Local-Site_timezone,unaware
# 2021-10-31T04:00:00,14472334024.676216,FarAway-Site_timezone,unaware
# 2021-10-31T05:00:00,23416728348.467678,FarAway-Site_timezone,unaware
# 2021-10-31T06:00:00,37889062373.14389,FarAway-Site_timezone,unaware
# 2021-10-31T07:00:00,61305790721.61157,FarAway-Site_timezone,unaware
# 2021-10-31T08:00:00,99194853094.75546,FarAway-Site_timezone,unaware
# 2021-10-31T09:00:00,160500643816.36703,FarAway-Site_timezone,unaware
# 2021-10-31T10:00:00,259695496911.1225,FarAway-Site_timezone,unaware
# ```
# API get data (UTC)
# ```
# [
#   {
#     "date": "2021-10-30T23:00:00",
#     "variableId": 2441335,
#     "rawValue": 61305790721.61157,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T22:00:00",
#     "variableId": 2441335,
#     "rawValue": 37889062373.14389,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T04:00:00",
#     "variableId": 2441335,
#     "rawValue": 679891637638.612,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T03:00:00",
#     "variableId": 2441335,
#     "rawValue": 420196140727.4895,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441335,
#     "rawValue": 259695496911.1225,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T01:00:00",
#     "variableId": 2441335,
#     "rawValue": 160500643816.36703,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T00:00:00",
#     "variableId": 2441335,
#     "rawValue": 99194853094.75546,
#     "unitId": 0
#   }
# ]
# ```
# API get data (Local)
# ```
# [
#   {
#     "date": "2021-10-31T04:00:00",
#     "variableId": 2441335,
#     "rawValue": 14472334024.676216,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T03:00:00",
#     "variableId": 2441335,
#     "rawValue": 8944394323.791462,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T02:00:00",
#     "variableId": 2441335,
#     "rawValue": 5527939700.884755,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T01:00:00",
#     "variableId": 2441335,
#     "rawValue": 3416454622.906706,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-31T00:00:00",
#     "variableId": 2441335,
#     "rawValue": 2111485077.9780493,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T23:00:00",
#     "variableId": 2441335,
#     "rawValue": 1304969544.9286566,
#     "unitId": 0
#   },
#   {
#     "date": "2021-10-30T22:00:00",
#     "variableId": 2441335,
#     "rawValue": 806515533.0493927,
#     "unitId": 0
#   }
# ]
# ```

# %% [markdown]
# # Variables calculées
